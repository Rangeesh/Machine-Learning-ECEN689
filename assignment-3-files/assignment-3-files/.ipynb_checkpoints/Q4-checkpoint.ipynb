# %%
import numpy as np
import pandas as pd
import random 
import math
import matplotlib.pyplot as plt
from scipy.stats import norm
from sys import maxsize

# %%
a=np.loadtxt(open("1D_regression_data.csv", "rb"))
c1=list(range(0,100))
rds=random.sample(c1,70)
rds_sort=np.sort(rds)
x=np.transpose(a[rds_sort,0])
y=np.transpose(a[rds_sort,1])

# %%
l=0.1

# %%
#Linear
A1=np.array([x,np.ones(70)]).T
W_star1=np.matmul(np.linalg.inv(np.matmul(A1.T,A1)+l*np.eye(2)),np.matmul(A1.T,y))
W_star1
cost1=np.dot((y-np.matmul(A1,W_star1.T)),(y-np.matmul(A1,W_star1.T)))/70
cost1
# Out:
# 246.83301824018918

# %%
fig,ax = plt.subplots()
ax.plot(x,y,'--g',label='given class 1')
ax.plot(x,(np.matmul(A1,W_star1.T)),'--b',label='given class 2')
leg = ax.legend();
plt.xlabel('x')
plt.ylabel('class conditional densities')
plt.title('3a) EM and Ideal')
plt.savefig('3aEM2.png')

# %%
(y-np.matmul(A1,W_star1.T))
# Out:
# array([ 10.59153791,   8.41239713,  13.05185469,  12.62500436,
#         11.62812167,  11.22875334,  10.47398275,   9.3722486 ,
#         10.91414075,  11.36108537,  13.00411959,   9.38670127,
#          9.69599864,   8.55669005,  10.01533094,   9.16972181,
#          4.8153602 ,   8.93549565,   3.90109913,   3.7608612 ,
#          4.41932426,   2.52367662,   1.02524871,   1.87049463,
#          0.2596301 ,  -4.32626129,  -0.16746823,  -6.81733357,
#         -6.54982343, -12.03319843,  -8.17829264, -11.61226247,
#        -10.96131257, -10.52410165, -10.19476853, -10.66100516,
#        -11.23602803, -16.35160466, -14.45209167, -17.17039125,
#        -15.21523969, -13.73360252, -16.05363386, -20.42984822,
#        -16.96707268, -21.39823391, -16.01581814, -17.78460456,
#        -21.36437598, -18.02381842, -17.7009982 , -17.43009013,
#        -18.87195423, -15.82330037, -13.92170829, -14.23483094,
#        -11.16817809, -15.191692  ,   0.0654139 ,   0.64658765,
#          1.05573626,  12.69628505,  15.7501677 ,  17.77228541,
#         17.94090142,  23.85318913,  34.76941125,  40.80849734,
#         42.20264468,  45.19820949])

# %%
#Square
A2=np.array([np.power(x,2),x,np.ones(70)]).T
W_star2=np.matmul(np.linalg.inv(np.matmul(A2.T,A2)+l*np.eye(3)),np.matmul(A2.T,y))
W_star2
cost2=np.dot((y-np.matmul(A2,W_star2.T)),(y-np.matmul(A2,W_star2.T)))/70
cost2
# Out:
# 65.58857786411426

# %%
fig,ax = plt.subplots()
ax.plot(x,y,'--g',label='given class 1')
ax.plot(x,(np.matmul(A2,W_star2.T)),'--b',label='given class 2')
leg = ax.legend();
plt.xlabel('x')
plt.ylabel('class conditional densities')
plt.title('3a) EM and Ideal')
plt.savefig('3aEM2.png')

# %%
#Cube
A3=np.array([np.power(x,3),np.power(x,2),x,np.ones(70)]).T
W_star3=np.matmul(np.linalg.inv(np.matmul(A3.T,A3)+l*np.eye(4)),np.matmul(A3.T,y))
W_star3
# Out:
# array([ 0.24937478,  1.23929252, -2.96160015, -2.51050094])

# %%
cost3=np.dot((y-np.matmul(A3,W_star3.T)),(y-np.matmul(A3,W_star3.T)))/70
cost3
# Out:
# 3.6125523634970995

# %%
fig,ax = plt.subplots()
ax.plot(x,y,'--g',label='given class 1')
ax.plot(x,(np.matmul(A3,W_star3.T)),'--b',label='given class 2')
leg = ax.legend();
plt.xlabel('x')
plt.ylabel('class conditional densities')
plt.title('3a) EM and Ideal')
plt.savefig('3aEM2.png')

# %%
#Fourth
A4=np.array([np.power(x,4),np.power(x,3),np.power(x,2),x,np.ones(70)]).T
W_star4=np.matmul(np.linalg.inv(np.matmul(A4.T,A4)+l*np.eye(5)),np.matmul(A4.T,y))
W_star4
# Out:
# array([ 0.00335194,  0.24989858,  1.13774568, -2.97802692, -2.1958844 ])

# %%
cost4=np.dot((y-np.matmul(A4,W_star4.T)),(y-np.matmul(A4,W_star4.T)))/70
cost4
# Out:
# 3.518305452801634

# %%
fig,ax = plt.subplots()
ax.plot(x,y,'--g',label='given class 1')
ax.plot(x,(np.matmul(A4,W_star4.T)),'--b',label='given class 2')
leg = ax.legend();
plt.xlabel('x')
plt.ylabel('class conditional densities')
plt.title('3a) EM and Ideal')
plt.savefig('3aEM2.png')

# %%
#Fifth
A5=np.array([np.power(x,5),np.power(x,4),np.power(x,3),np.power(x,2),x,np.ones(70)]).T
W_star5=np.matmul(np.linalg.inv(np.matmul(A5.T,A5)+l*np.eye(6)),np.matmul(A5.T,y))
W_star5
# Out:
# array([-1.04148858e-03,  3.11694740e-03,  2.90417784e-01,  1.14575403e+00,
#        -3.27417878e+00, -2.21703747e+00])

# %%
cost5=np.dot((y-np.matmul(A5,W_star5.T)),(y-np.matmul(A5,W_star5.T)))/70
cost5
# Out:
# 3.434899622880078

# %%
fig,ax = plt.subplots()
ax.plot(x,y,'--g',label='given class 1')
ax.plot(x,(np.matmul(A5,W_star5.T)),'--b',label='given class 2')
leg = ax.legend();
plt.xlabel('x')
plt.ylabel('class conditional densities')
plt.title('3a) EM and Ideal')
plt.savefig('3aEM2.png')

# %%
rds_rem=np.setdiff1d(range(0,100),rds_sort)
xt=np.transpose(a[rds_rem,0])
yt=np.transpose(a[rds_rem,1])

# %%
A1t=np.array([xt,np.ones(30)]).T
cost1t=np.dot((yt-np.matmul(A1t,W_star1.T)),(yt-np.matmul(A1t,W_star1.T)))/30
cost1t
# Out:
# 185.14444296046986

# %%
A2t=np.array([np.power(xt,2),xt,np.ones(30)]).T
cost2t=np.dot((yt-np.matmul(A2t,W_star2.T)),(yt-np.matmul(A2t,W_star2.T)))/30
cost2t
# Out:
# 68.87478048985066

# %%
A3t=np.array([np.power(xt,3),np.power(xt,2),xt,np.ones(30)]).T
cost3t=np.dot((yt-np.matmul(A3t,W_star3.T)),(yt-np.matmul(A3t,W_star3.T)))/30
cost3t
# Out:
# 2.8990376598953125

# %%
A4t=np.array([np.power(xt,4),np.power(xt,3),np.power(xt,2),xt,np.ones(30)]).T
cost4t=np.dot((yt-np.matmul(A4t,W_star4.T)),(yt-np.matmul(A4t,W_star4.T)))/30
cost4t
# Out:
# 2.9116802917289353

# %%
A5t=np.array([np.power(xt,5),np.power(xt,4),np.power(xt,3),np.power(xt,2),xt,np.ones(30)]).T
cost5t=np.dot((yt-np.matmul(A5t,W_star5.T)),(yt-np.matmul(A5t,W_star5.T)))/30
cost5t
# Out:
# 2.4717096667402845

# %%
fig,ax = plt.subplots()
ax.plot(xt,yt,'--g',label='given class 1')
ax.plot(xt,(np.matmul(A1t,W_star1.T)),'--b',label='given class 2')
ax.plot(xt,(np.matmul(A2t,W_star2.T)),'--r',label='given class 2')
ax.plot(xt,(np.matmul(A3t,W_star3.T)),'--c',label='given class 2')
ax.plot(xt,(np.matmul(A4t,W_star4.T)),'--y',label='given class 2')
ax.plot(xt,(np.matmul(A5t,W_star5.T)),'--k',label='given class 2')

leg = ax.legend();
plt.xlabel('x')
plt.ylabel('class conditional densities')
plt.title('3a) EM and Ideal')
plt.savefig('3aEM2.png')
