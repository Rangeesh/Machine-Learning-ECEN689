# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.mlab as mlab
import math

mu1 = 0
variance1 = 4
sigma1 = math.sqrt(variance1)
mu2= 4
variance2 = 4
sigma2 = math.sqrt(variance2)

mu3 = 8
variance3 = 5
sigma3 = math.sqrt(variance3)
mu4= 12
variance4 = 5
sigma4= math.sqrt(variance4)

x = np.linspace(-8, 20, 100)

mu11 = -0.291311
sigma11 = 1.782934

mu21= 4.332953
sigma21 = 1.77231

mu31 = 7.703065
sigma31 = 1.662945

mu41= 12.089492
sigma41 = 1.293634


fig,ax = plt.subplots()
ax.plot(x,0.5*mlab.normpdf(x, mu1, sigma1)+0.5*mlab.normpdf(x,mu2,sigma2),'--g',label='given class 1')
ax.plot(x,0.5*mlab.normpdf(x, mu3, sigma3)+0.5*mlab.normpdf(x,mu4,sigma4),'--b',label='given class 2')
ax.plot(x,0.44*mlab.normpdf(x, mu11, sigma11)+0.56*mlab.normpdf(x,mu21,sigma21),'-g',label='EM Class1 ')
ax.plot(x,0.56*mlab.normpdf(x, mu31, sigma31)+0.44*mlab.normpdf(x,mu41,sigma41),'-b',label='EM Class2')

leg = ax.legend();
plt.xlabel('x')
plt.ylabel('class conditional densities')
plt.title('3a) EM and Ideal')
plt.savefig('3aEM2.png')
# Out:
# C:\Users\range\.julia\conda\3\lib\site-packages\ipykernel_launcher.py:36: MatplotlibDeprecationWarning: scipy.stats.norm.pdf
# C:\Users\range\.julia\conda\3\lib\site-packages\ipykernel_launcher.py:37: MatplotlibDeprecationWarning: scipy.stats.norm.pdf
# C:\Users\range\.julia\conda\3\lib\site-packages\ipykernel_launcher.py:38: MatplotlibDeprecationWarning: scipy.stats.norm.pdf
# C:\Users\range\.julia\conda\3\lib\site-packages\ipykernel_launcher.py:39: MatplotlibDeprecationWarning: scipy.stats.norm.pdf

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.mlab as mlab
import math

mu1 = 0
variance1 = 4
sigma1 = math.sqrt(variance1)
mu2= 8
variance2 = 5
sigma2 = math.sqrt(variance2)

mu3 = 4
variance3 = 4
sigma3 = math.sqrt(variance3)
mu4= 12
variance4 = 5
sigma4= math.sqrt(variance4)

x = np.linspace(-10, 20, 100)

params1 = { 'mu1': [3.867693],
          'sig1': [1.915206] ,
          'mu2': [12.176416],
          'sig2': [2.266246],
          'lambda1': [0.41],
          'lambda2': [0.59]
        }

mu11 = 0.177544
sigma11 = 1.478103

mu21= 7.709498
sigma21 = 2.146186

mu31 = 3.867693
sigma31 = 1.915206

mu41= 12.176416
sigma41 = 2.266246


fig,ax = plt.subplots()
ax.plot(x,0.5*mlab.normpdf(x, mu1, sigma1)+0.5*mlab.normpdf(x,mu2,sigma2),'--g',label='given Class1')
ax.plot(x,0.5*mlab.normpdf(x, mu3, sigma3)+0.5*mlab.normpdf(x,mu4,sigma4),'--b',label='given Class2')
ax.plot(x,0.43*mlab.normpdf(x, mu11, sigma11)+0.57*mlab.normpdf(x,mu21,sigma21),'-g',label='EM Class1')
ax.plot(x,0.41*mlab.normpdf(x, mu31, sigma31)+0.59*mlab.normpdf(x,mu41,sigma41),'-b',label='EM Class2')

leg = ax.legend();
plt.xlabel('x')
plt.ylabel('class conditional densities')
plt.title('3b) EM and Ideal')
plt.savefig('3bEM2.png')
# Out:
# C:\Users\range\.julia\conda\3\lib\site-packages\ipykernel_launcher.py:44: MatplotlibDeprecationWarning: scipy.stats.norm.pdf
# C:\Users\range\.julia\conda\3\lib\site-packages\ipykernel_launcher.py:45: MatplotlibDeprecationWarning: scipy.stats.norm.pdf
# C:\Users\range\.julia\conda\3\lib\site-packages\ipykernel_launcher.py:46: MatplotlibDeprecationWarning: scipy.stats.norm.pdf
# C:\Users\range\.julia\conda\3\lib\site-packages\ipykernel_launcher.py:47: MatplotlibDeprecationWarning: scipy.stats.norm.pdf

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.mlab as mlab
import math

mu1 = 0
variance1 = 4
sigma1 = math.sqrt(variance1)
mu2= 4
variance2 = 4
sigma2 = math.sqrt(variance2)

mu3 = 8
variance3 = 5
sigma3 = math.sqrt(variance3)
mu4= 12
variance4 = 5
sigma4= math.sqrt(variance4)

x = np.linspace(-10, 20, 100)

mu11 = 2.2982767
sigma11 = 2.8919672977106967



mu31 = 9.6330929
sigma31 = 2.642249191524257




fig,ax = plt.subplots()
ax.plot(x,0.5*mlab.normpdf(x, mu1, sigma1)+0.5*mlab.normpdf(x,mu2,sigma2),'--g',label='given Class1')
ax.plot(x,0.5*mlab.normpdf(x, mu3, sigma3)+0.5*mlab.normpdf(x,mu4,sigma4),'--b',label='given Class2')
ax.plot(x,mlab.normpdf(x, mu11, sigma11),'-g',label='normal Class1')
ax.plot(x,mlab.normpdf(x, mu31, sigma31),'-b',label='normal Class2')

leg = ax.legend();
plt.xlabel('x')
plt.ylabel('class conditional densities')
plt.title('3a) Normal Bayes and Ideal')
plt.savefig('3aBayes2.png')
# Out:
# C:\Users\range\.julia\conda\3\lib\site-packages\ipykernel_launcher.py:34: MatplotlibDeprecationWarning: scipy.stats.norm.pdf
# C:\Users\range\.julia\conda\3\lib\site-packages\ipykernel_launcher.py:35: MatplotlibDeprecationWarning: scipy.stats.norm.pdf
# C:\Users\range\.julia\conda\3\lib\site-packages\ipykernel_launcher.py:36: MatplotlibDeprecationWarning: scipy.stats.norm.pdf
# C:\Users\range\.julia\conda\3\lib\site-packages\ipykernel_launcher.py:37: MatplotlibDeprecationWarning: scipy.stats.norm.pdf

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.mlab as mlab
import math

mu1 = 0
variance1 = 4
sigma1 = math.sqrt(variance1)
mu2= 8
variance2 = 5
sigma2 = math.sqrt(variance2)

mu3 = 4
variance3 = 4
sigma3 = math.sqrt(variance3)
mu4= 12
variance4 = 5
sigma4= math.sqrt(variance4)

x = np.linspace(-10, 20, 100)

mu11 = 4.4707577999999994
sigma11 = 4.171526959645012



mu31 = 8.769839999999999
sigma31 = 4.598429040794911




fig,ax = plt.subplots()
ax.plot(x,0.5*mlab.normpdf(x, mu1, sigma1)+0.5*mlab.normpdf(x,mu2,sigma2),'--g',label='given Class1')
ax.plot(x,0.5*mlab.normpdf(x, mu3, sigma3)+0.5*mlab.normpdf(x,mu4,sigma4),'--b',label='given Class2')
ax.plot(x,mlab.normpdf(x, mu11, sigma11),'-g',label='normal Class1')
ax.plot(x,mlab.normpdf(x, mu31, sigma31),'-b',label='normal Class2')

leg = ax.legend();
plt.xlabel('x')
plt.ylabel('class conditional densities')
plt.title('3b) Normal Bayes and Ideal')
plt.savefig('3bBayes2.png')
# Out:
# C:\Users\range\.julia\conda\3\lib\site-packages\ipykernel_launcher.py:34: MatplotlibDeprecationWarning: scipy.stats.norm.pdf
# C:\Users\range\.julia\conda\3\lib\site-packages\ipykernel_launcher.py:35: MatplotlibDeprecationWarning: scipy.stats.norm.pdf
# C:\Users\range\.julia\conda\3\lib\site-packages\ipykernel_launcher.py:36: MatplotlibDeprecationWarning: scipy.stats.norm.pdf
# C:\Users\range\.julia\conda\3\lib\site-packages\ipykernel_launcher.py:37: MatplotlibDeprecationWarning: scipy.stats.norm.pdf
